# %% [markdown]
# # LOG6302A - Lab4

# %% [markdown]
# CESAR Pierre 2310298
#
# MERSALI Bilal 2309771

# %% [markdown]
# ### Imports

# %%
#change execuction directory for the google colab use
import os
from code_analysis import CFG, CFGReader

# %% [markdown]
# # Partie 1: Extraction du DataFlow

# %%
class CFGVisitor:
	def __init__(self, cfg: CFG):
		self.cfg = cfg
		self.defs = self.all_defs()
		self.refs = self.all_refs()
		# print("self.defs:",self.defs)
		# print("self.refs:",self.refs)


	def all_defs(self) -> set:
		defs = set()
		for node in self.cfg.get_node_ids():
			if self.cfg.get_type(node) == "BinOP" and self.cfg.get_image(node) == "=":
				left_op_node = self.cfg.get_op_hands(node)[0]
				if self.cfg.get_type(left_op_node) == "Variable":
					defs.add(left_op_node)
		return defs

	def all_refs(self) -> set:
		refs = set()
		for node in self.cfg.get_node_ids():
			if self.cfg.get_type(node) == "Variable" and not(node in self.defs):
				refs.add(node)
		return refs

	def def_in_node(self, node:int) -> int:
		if node in self.defs:
			return node
			# return self.defs[node] # Left op node

	def reaching_defs(self):
		IN = {}
		OUT = {}
		GEN = {}
		KILL = {}

		for node in self.cfg.get_node_ids():
			IN[node] = set()
			OUT[node] = set()
			KILL[node] = set()
			left_op_node = self.def_in_node(node)
			if left_op_node is not None:
				GEN[node] = {left_op_node}
				for node2 in self.cfg.get_node_ids():
					left_op_node2 = self.def_in_node(node2)
					if self.cfg.get_image(left_op_node2) == self.cfg.get_image(left_op_node):
						KILL[node].add(node2)
			else:
				GEN[node] = set()

		changes = True
		while changes:
			changes = False
			for node in self.cfg.get_node_ids():
				for parent in self.cfg.get_parents(node):
					IN[node] = IN[node].union(OUT[parent])
				call_begin = self.cfg.get_call_begin(node)
				if call_begin != None:
					IN[node] = IN[node].union(OUT[call_begin])
				old_OUT = OUT[node]
				OUT[node] = GEN[node].union(IN[node].difference(KILL[node]))
				if OUT[node] != old_OUT:
					changes = True

		return IN, OUT

	def ref_in_node(self, node:int) -> set:
		if node in self.refs:
			return node

	def reachable_refs(self):
		IN = {}
		OUT = {}
		GEN = {}
		KILL = {}

		for node in self.cfg.get_node_ids():
			IN[node] = set()
			OUT[node] = set()
			GEN[node] = set()
			KILL[node] = set()
			possible_ref = self.ref_in_node(node)
			if possible_ref is not None: # if node is Variable reference
				GEN[node] = {node}

			possible_def = self.def_in_node(node)
			if possible_def is not None: # if node is Variable definition
				for node2 in self.cfg.get_node_ids():
					if self.ref_in_node(node2) is not None and self.cfg.get_image(node2) == self.cfg.get_image(possible_def):
						KILL[node].add(node2)

		changes = True
		while changes:
			changes = False
			for node in self.cfg.get_node_ids():
				for child in self.cfg.get_children(node):
					OUT[node] = OUT[node].union(IN[child])
				call_end = self.cfg.get_call_end(node)
				if call_end != None:
					OUT[node] = OUT[node].union(IN[call_end])
				old_IN = IN[node]
				IN[node] = GEN[node].union(OUT[node].difference(KILL[node]))
				if IN[node] != old_IN:
					changes = True

		return IN, OUT

	def get_var(self) -> set:
		var_set = set()
		for node in self.cfg.get_node_ids():
			if self.cfg.get_type(node) == "Variable":
				var_set.add(self.cfg.get_image(node))
		return var_set

	def get_nodes_number(self) -> int:
		return len(self.cfg.get_node_ids())

	def get_edges_number(self) -> int:
		edges_number = 0
		for node in self.cfg.get_node_ids():
			edges_number += len(self.cfg.get_children(node))
		return edges_number

	def find_pair_ref_def(self) -> set:
		IN_def, OUT_def = self.reaching_defs()
		pairs_ref_def = set()
		for ref in self.refs:
			var = self.cfg.get_image(ref)
			associated_defs = set()
			for definition in OUT_def[ref]:
				if self.cfg.get_image(definition) == var:
					associated_defs.add(definition)
			for associated_def in associated_defs:
				# print(f"La référence au noeud {ref} de la variable {var} provient possiblement de la définition au noeud {associated_def}")
				pairs_ref_def.add((ref,associated_def))
		return pairs_ref_def

	def find_pair_def_ref(self) -> set:
		IN_ref, OUT_ref = self.reachable_refs()
		pairs_def_ref = set()
		for definition in self.defs:
			var = self.cfg.get_image(definition)
			associated_refs = set()
			for ref in OUT_ref[definition]:
				if self.cfg.get_image(ref) == var:
					associated_refs.add(ref)
			for associated_ref in associated_refs:
				# print(f"La définition au noeud {definition} de la variable {var} est possiblement utilisé au noeud {associated_ref}")
				pairs_def_ref.add((definition,associated_ref))
		return pairs_def_ref

	def find_ref_not_defined(self) -> set:
		IN_def, OUT_def = self.reaching_defs()
		ref_not_defined = set()
		for ref in self.refs:
			defined = False
			var = self.cfg.get_image(ref)
			for definition in IN_def[ref]:
				if self.cfg.get_image(definition) == var:
					defined = True
					break
			if not defined:
				ref_not_defined.add(ref)
		return ref_not_defined

	def find_def_not_referenced(self) -> set:
		IN_ref, OUT_ref = self.reachable_refs()
		def_not_referenced = set()
		for definition in self.defs:
			referenced = False
			var = self.cfg.get_image(definition)
			for ref in OUT_ref[definition]:
				if self.cfg.get_image(ref) == var:
					referenced = True
					break
			if not referenced:
				def_not_referenced.add(definition)
		return def_not_referenced

	def find_prepare_query_nodes(self):
		prepare_query_nodes = []
		for node in self.cfg.get_node_ids():
			if self.cfg.get_type(node) == "CallBegin" and self.cfg.get_image(node) == "prepare_query":
				prepare_query_nodes.append(node)
		return prepare_query_nodes

	def assert_def_comes_from_filter_var(self, node):
		#1 assert node type is Variable
		if self.cfg.get_type(node) != "Variable":
			return False
		#retrive the binOp child
		binOp_child = self.cfg.get_children(node)[0]
		#2 assert node type is BinOP
		if self.cfg.get_type(binOp_child) != "BinOP":
			return False
		#retrive the 2nc part of the binOp
		node_to_look = self.cfg.get_op_hands(binOp_child)[1]
		seek = True
		while seek:
			#3 assert node type is BinOP
			if self.cfg.get_image(node_to_look) == "filter_var":
				seek = False
				return True
			elif self.cfg.get_type(node_to_look) == "RetValue":
				node_to_look = self.cfg.get_parents(node_to_look)[0]
			else:
				return False
	
	def check_prepare_query_params_filtered(self):
		prepare_query_nodes = self.find_prepare_query_nodes()
		for node in prepare_query_nodes:
			params = self.cfg.get_call_args(node)
			#filter params with filter_var
			params = [param for param in params if self.cfg.get_type(param) == "Variable"]
			for param in params:
				filtered = True
				defs_nodes_in,_ = self.reaching_defs()

				defs_nodes = [n for n in defs_nodes_in[param] if self.cfg.get_image(n) == self.cfg.get_image(param)]
				for def_node in defs_nodes:
			
					if not self.assert_def_comes_from_filter_var(def_node):
						filtered = False
				if not filtered:
					print(f"Parameter {self.cfg.get_image(param)} of prepare_query at line {self.cfg.get_position(node)[0]} is not filtered or not filtered every time by filter_var")

# %% [markdown]
# # Partie 2 : Utilisation du Dataflow
#
# ## 2.1 Variable vive/morte

# %%
def find_ref_not_defined(cfg_visitor) -> set:
  IN_def, OUT_def = cfg_visitor.reaching_defs()
  ref_not_defined = set()
  for ref in cfg_visitor.refs:
    defined = False
    var = cfg_visitor.cfg.get_image(ref)
    for definition in IN_def[ref]:
      if cfg_visitor.cfg.get_image(definition) == var:
        defined = True
        break
    if not defined:
      ref_not_defined.add(ref)
  return ref_not_defined

def find_def_not_referenced(cfg_visitor) -> set:
  IN_ref, OUT_ref = cfg_visitor.reachable_refs()
  def_not_referenced = set()
  for definition in cfg_visitor.defs:
    referenced = False
    var = cfg_visitor.cfg.get_image(definition)
    for ref in OUT_ref[definition]:
      if cfg_visitor.cfg.get_image(ref) == var:
        referenced = True
        break
    if not referenced:
      def_not_referenced.add(definition)
  return def_not_referenced

# %%
def visit_one_file(filename: str):
	reader = CFGReader()
	cfg = reader.read_cfg(filename)
	visitor = CFGVisitor(cfg)
	return visitor

def part2(directory: str) -> None:
	for filename in os.scandir(directory):
		if filename.is_file() and filename.name.endswith(".php.cfg.json"):
			visitor = visit_one_file(filename.path)
			print("For file:",filename.path)
			ref_not_defined = visitor.find_ref_not_defined()
			def_not_referenced = visitor.find_def_not_referenced()
			print("\tRéférences non définies:")#,ref_not_defined)
			for ref in ref_not_defined:
				print(f"\t\tVariable {visitor.cfg.get_image(ref)}, ligne {visitor.cfg.get_position(ref)[0]}")
			print("\tDéfinitions non référencées/utilisées:")#,def_not_referenced)
			for definition in def_not_referenced:
				print(f"\t\tVariable {visitor.cfg.get_image(definition)}, ligne {visitor.cfg.get_position(definition)[0]}")
			print("\n")

part2("../tp4/part_2/")
# Out:
# For file: ../tp4/part_2/file3.php.cfg.json
# 	Références non définies:
# 		Variable this, ligne 1917
# 		Variable this, ligne 1917
# 		Variable this, ligne 2620
# 		Variable value, ligne 3293
# 		Variable field, ligne 2620
# 		Variable value, ligne 3293
# 		Variable this, ligne 2621
# 		Variable field, ligne 2621
# 		Variable string, ligne 1239
# 		Variable data, ligne 2624
# 		Variable field, ligne 2624
# 		Variable string, ligne 1253
# 		Variable data, ligne 2627
# 		Variable value, ligne 3295
# 		Variable data, ligne 2640
# 		Variable table, ligne 2640
# 		Variable string, ligne 1254
# 		Variable data, ligne 2641
# 		Variable field, ligne 2641
# 		Variable this, ligne 1930
# 		Variable value, ligne 2641
# 		Variable value, ligne 3296
# 		Variable this, ligne 1258
# 		Variable value, ligne 2642
# 		Variable show_errors, ligne 65
# 		Variable this, ligne 1259
# 		Variable this, ligne 1933
# 		Variable suppress_errors, ligne 74
# 		Variable value, ligne 3296
# 		Variable value, ligne 2642
# 		Variable last_error, ligne 83
# 		Variable value, ligne 2647
# 		Variable num_queries, ligne 92
# 		Variable value, ligne 3302
# 		Variable this, ligne 1260
# 		Variable num_rows, ligne 101
# 		Variable this, ligne 2649
# 		Variable string, ligne 1260
# 		Variable rows_affected, ligne 110
# 		Variable this, ligne 1937
# 		Variable value, ligne 3305
# 		Variable insert_id, ligne 119
# 		Variable table, ligne 2649
# 		Variable field, ligne 2649
# 		Variable last_query, ligne 128
# 		Variable last_result, ligne 137
# 		Variable string, ligne 1262
# 		Variable result, ligne 155
# 		Variable value, ligne 2649
# 		Variable data, ligne 3309
# 		Variable col_meta, ligne 164
# 		Variable col, ligne 3309
# 		Variable table_charset, ligne 173
# 		Variable value, ligne 3309
# 		Variable this, ligne 1262
# 		Variable check_current_query, ligne 182
# 		Variable value, ligne 2650
# 		Variable checking_collation, ligne 192
# 		Variable this, ligne 1265
# 		Variable col_info, ligne 201
# 		Variable value, ligne 3310
# 		Variable queries, ligne 225
# 		Variable value, ligne 2655
# 		Variable reconnect_retries, ligne 235
# 		Variable data, ligne 2655
# 		Variable field, ligne 2655
# 		Variable prefix, ligne 247
# 		Variable data, ligne 2658
# 		Variable base_prefix, ligne 256
# 		Variable ready, ligne 265
# 		Variable data, ligne 2671
# 		Variable blogid, ligne 274
# 		Variable value, ligne 3312
# 		Variable table, ligne 2671
# 		Variable siteid, ligne 283
# 		Variable data, ligne 2672
# 		Variable field, ligne 2672
# 		Variable tables, ligne 293
# 		Variable value, ligne 2672
# 		Variable value, ligne 3312
# 		Variable allow_bail, ligne 1954
# 		Variable value, ligne 2673
# 		Variable value, ligne 2673
# 		Variable value, ligne 3316
# 		Variable old_tables, ligne 316
# 		Variable value, ligne 2678
# 		Variable this, ligne 3319
# 		Variable global_tables, ligne 326
# 		Variable this, ligne 2680
# 		Variable string, ligne 1271
# 		Variable this, ligne 3320
# 		Variable ms_global_tables, ligne 336
# 		Variable this, ligne 1274
# 		Variable table, ligne 2680
# 		Variable this, ligne 3322
# 		Variable field, ligne 2680
# 		Variable value, ligne 2680
# 		Variable comments, ligne 353
# 		Variable commentmeta, ligne 362
# 		Variable links, ligne 371
# 		Variable options, ligne 380
# 		Variable this, ligne 3323
# 		Variable postmeta, ligne 389
# 		Variable data, ligne 1287
# 		Variable posts, ligne 398
# 		Variable value, ligne 2681
# 		Variable terms, ligne 407
# 		Variable term_relationships, ligne 416
# 		Variable term_taxonomy, ligne 425
# 		Variable data, ligne 1288
# 		Variable termmeta, ligne 434
# 		Variable value, ligne 2686
# 		Variable usermeta, ligne 447
# 		Variable data, ligne 1289
# 		Variable users, ligne 456
# 		Variable k, ligne 1289
# 		Variable blogs, ligne 465
# 		Variable v, ligne 1289
# 		Variable blogmeta, ligne 474
# 		Variable value, ligne 3329
# 		Variable registration_log, ligne 483
# 		Variable this, ligne 1965
# 		Variable signups, ligne 492
# 		Variable data, ligne 2689
# 		Variable site, ligne 501
# 		Variable v, ligne 1290
# 		Variable sitecategories, ligne 510
# 		Variable query, ligne 2707
# 		Variable sitemeta, ligne 519
# 		Variable this, ligne 1291
# 		Variable field_types, ligne 536
# 		Variable x, ligne 2707
# 		Variable y, ligne 2707
# 		Variable charset, ligne 545
# 		Variable value, ligne 3330
# 		Variable collate, ligne 554
# 		Variable v, ligne 1291
# 		Variable dbuser, ligne 563
# 		Variable this, ligne 2708
# 		Variable dbpassword, ligne 572
# 		Variable data, ligne 1291
# 		Variable dbname, ligne 581
# 		Variable this, ligne 3331
# 		Variable dbhost, ligne 590
# 		Variable k, ligne 1291
# 		Variable dbh, ligne 606
# 		Variable this, ligne 1293
# 		Variable func_call, ligne 615
# 		Variable this, ligne 2711
# 		Variable is_mysql, ligne 629
# 		Variable v, ligne 1293
# 		Variable value, ligne 3331
# 		Variable incompatible_modes, ligne 638
# 		Variable data, ligne 1293
# 		Variable k, ligne 1293
# 		Variable query, ligne 2711
# 		Variable col, ligne 3331
# 		Variable this, ligne 1297
# 		Variable this, ligne 2712
# 		Variable this, ligne 2715
# 		Variable use_mysqli, ligne 654
# 		Variable this, ligne 3334
# 		Variable has_connected, ligne 663
# 		Variable data, ligne 1297
# 		Variable time_start, ligne 674
# 		Variable query, ligne 2715
# 		Variable error, ligne 683
# 		Variable value, ligne 3334
# 		Variable data, ligne 1316
# 		Variable dbuser, ligne 700
# 		Variable col, ligne 3334
# 		Variable dbpassword, ligne 700
# 		Variable this, ligne 2719
# 		Variable dbname, ligne 700
# 		Variable y, ligne 2719
# 		Variable dbhost, ligne 700
# 		Variable data, ligne 3337
# 		Variable col, ligne 3337
# 		Variable this, ligne 1980
# 		Variable this, ligne 702
# 		Variable column, ligne 3342
# 		Variable query, ligne 3342
# 		Variable query, ligne 3343
# 		Variable this, ligne 2720
# 		Variable y, ligne 2720
# 		Variable query, ligne 3347
# 		Variable this, ligne 3350
# 		Variable query, ligne 2000
# 		Variable this, ligne 707
# 		Variable this, ligne 3351
# 		Variable data, ligne 1320
# 		Variable this, ligne 2001
# 		Variable x, ligne 2724
# 		Variable data, ligne 1321
# 		Variable k, ligne 1321
# 		Variable v, ligne 1321
# 		Variable this, ligne 2002
# 		Variable x, ligne 2724
# 		Variable x, ligne 2724
# 		Variable this, ligne 710
# 		Variable v, ligne 1322
# 		Variable dbuser, ligne 714
# 		Variable this, ligne 714
# 		Variable query, ligne 2016
# 		Variable this, ligne 1323
# 		Variable dbpassword, ligne 715
# 		Variable query, ligne 2741
# 		Variable this, ligne 715
# 		Variable output, ligne 2741
# 		Variable y, ligne 2741
# 		Variable dbname, ligne 716
# 		Variable v, ligne 1323
# 		Variable this, ligne 716
# 		Variable this, ligne 2019
# 		Variable dbhost, ligne 717
# 		Variable data, ligne 1323
# 		Variable this, ligne 717
# 		Variable k, ligne 1323
# 		Variable this, ligne 2023
# 		Variable this, ligne 1325
# 		Variable this, ligne 2742
# 		Variable query, ligne 2744
# 		Variable this, ligne 2745
# 		Variable v, ligne 1325
# 		Variable this, ligne 2745
# 		Variable this, ligne 2026
# 		Variable this, ligne 724
# 		Variable data, ligne 1325
# 		Variable k, ligne 1325
# 		Variable this, ligne 2029
# 		Variable this, ligne 1329
# 		Variable data, ligne 3356
# 		Variable query, ligne 2745
# 		Variable column, ligne 3356
# 		Variable this, ligne 2029
# 		Variable this, ligne 2746
# 		Variable data, ligne 1329
# 		Variable name, ligne 735
# 		Variable this, ligne 2749
# 		Variable name, ligne 736
# 		Variable query, ligne 2749
# 		Variable this, ligne 2030
# 		Variable this, ligne 737
# 		Variable string, ligne 1344
# 		Variable data, ligne 3358
# 		Variable column, ligne 3358
# 		Variable this, ligne 740
# 		Variable name, ligne 740
# 		Variable data, ligne 3363
# 		Variable this, ligne 2033
# 		Variable string, ligne 1345
# 		Variable this, ligne 2754
# 		Variable y, ligne 2754
# 		Variable name, ligne 751
# 		Variable query, ligne 3374
# 		Variable value, ligne 751
# 		Variable this, ligne 1346
# 		Variable output, ligne 2758
# 		Variable query, ligne 3376
# 		Variable string, ligne 1346
# 		Variable this, ligne 2035
# 		Variable this, ligne 2036
# 		Variable this, ligne 2759
# 		Variable name, ligne 757
# 		Variable query, ligne 1395
# 		Variable args, ligne 1395
# 		Variable y, ligne 2759
# 		Variable this, ligne 2759
# 		Variable y, ligne 2759
# 		Variable value, ligne 760
# 		Variable output, ligne 2760
# 		Variable this, ligne 760
# 		Variable name, ligne 760
# 		Variable query, ligne 3378
# 		Variable this, ligne 3381
# 		Variable query, ligne 1396
# 		Variable this, ligne 2040
# 		Variable this, ligne 2761
# 		Variable name, ligne 771
# 		Variable y, ligne 2761
# 		Variable query, ligne 3381
# 		Variable this, ligne 2046
# 		Variable query, ligne 1401
# 		Variable this, ligne 772
# 		Variable name, ligne 772
# 		Variable this, ligne 2049
# 		Variable this, ligne 3383
# 		Variable this, ligne 2051
# 		Variable this, ligne 2761
# 		Variable y, ligne 2761
# 		Variable name, ligne 782
# 		Variable output, ligne 2762
# 		Variable this, ligne 783
# 		Variable name, ligne 783
# 		Variable this, ligne 2763
# 		Variable y, ligne 2763
# 		Variable this, ligne 2055
# 		Variable query, ligne 3390
# 		Variable this, ligne 2056
# 		Variable this, ligne 2763
# 		Variable this, ligne 3393
# 		Variable y, ligne 2763
# 		Variable this, ligne 2057
# 		Variable query, ligne 3397
# 		Variable output, ligne 2764
# 		Variable args, ligne 1416
# 		Variable this, ligne 3403
# 		Variable this, ligne 2058
# 		Variable this, ligne 2766
# 		Variable y, ligne 2766
# 		Variable args, ligne 1416
# 		Variable this, ligne 2766
# 		Variable y, ligne 2766
# 		Variable this, ligne 2768
# 		Variable this, ligne 2065
# 		Variable args, ligne 1416
# 		Variable args, ligne 1418
# 		Variable this, ligne 2066
# 		Variable query, ligne 2785
# 		Variable x, ligne 2785
# 		Variable arg, ligne 1421
# 		Variable table, ligne 3421
# 		Variable query, ligne 2786
# 		Variable column, ligne 3421
# 		Variable value, ligne 3421
# 		Variable this, ligne 810
# 		Variable this, ligne 2787
# 		Variable arg, ligne 1422
# 		Variable this, ligne 2073
# 		Variable this, ligne 2787
# 		Variable value, ligne 3422
# 		Variable query, ligne 2787
# 		Variable value, ligne 3423
# 		Variable arg, ligne 1422
# 		Variable this, ligne 2074
# 		Variable this, ligne 3426
# 		Variable this, ligne 812
# 		Variable this, ligne 2788
# 		Variable this, ligne 2791
# 		Variable table, ligne 3426
# 		Variable this, ligne 2075
# 		Variable this, ligne 813
# 		Variable column, ligne 3426
# 		Variable query, ligne 2791
# 		Variable charset, ligne 832
# 		Variable collate, ligne 832
# 		Variable value, ligne 3429
# 		Variable this, ligne 2077
# 		Variable this, ligne 2796
# 		Variable this, ligne 833
# 		Variable this, ligne 2083
# 		Variable this, ligne 833
# 		Variable column, ligne 3436
# 		Variable this, ligne 2084
# 		Variable value, ligne 3437
# 		Variable arg, ligne 1429
# 		Variable this, ligne 833
# 		Variable this, ligne 3439
# 		Variable this, ligne 2797
# 		Variable this, ligne 2085
# 		Variable table, ligne 3439
# 		Variable column, ligne 3439
# 		Variable this, ligne 2085
# 		Variable this, ligne 2798
# 		Variable this, ligne 3443
# 		Variable query, ligne 1454
# 		Variable charset, ligne 837
# 		Variable this, ligne 837
# 		Variable this, ligne 2087
# 		Variable x, ligne 2798
# 		Variable this, ligne 2090
# 		Variable query, ligne 2821
# 		Variable output, ligne 2821
# 		Variable column, ligne 3448
# 		Variable this, ligne 841
# 		Variable this, ligne 2822
# 		Variable this, ligne 2091
# 		Variable query, ligne 3459
# 		Variable this, ligne 2091
# 		Variable query, ligne 2824
# 		Variable this, ligne 2825
# 		Variable query, ligne 3461
# 		Variable this, ligne 2825
# 		Variable this, ligne 2093
# 		Variable query, ligne 2825
# 		Variable collate, ligne 843
# 		Variable this, ligne 2097
# 		Variable this, ligne 2826
# 		Variable this, ligne 2099
# 		Variable this, ligne 2829
# 		Variable query, ligne 2829
# 		Variable matches, ligne 1463
# 		Variable this, ligne 2100
# 		Variable output, ligne 2835
# 		Variable this, ligne 2103
# 		Variable this, ligne 2837
# 		Variable output, ligne 2838
# 		Variable this, ligne 2841
# 		Variable this, ligne 856
# 		Variable this, ligne 2842
# 		Variable maybe, ligne 3479
# 		Variable row, ligne 2842
# 		Variable this, ligne 2108
# 		Variable row, ligne 2843
# 		Variable maybe, ligne 3481
# 		Variable this, ligne 2110
# 		Variable dbh, ligne 872
# 		Variable charset, ligne 872
# 		Variable maybe, ligne 3485
# 		Variable collate, ligne 872
# 		Variable this, ligne 2111
# 		Variable maybe, ligne 3486
# 		Variable this, ligne 2111
# 		Variable row, ligne 2846
# 		Variable charset, ligne 873
# 		Variable output, ligne 2851
# 		Variable this, ligne 874
# 		Variable this, ligne 2113
# 		Variable maybe, ligne 3496
# 		Variable output, ligne 2851
# 		Variable this, ligne 2113
# 		Variable this, ligne 2853
# 		Variable collate, ligne 876
# 		Variable this, ligne 2854
# 		Variable this, ligne 877
# 		Variable maybe, ligne 3497
# 		Variable row, ligne 2854
# 		Variable args_counts, ligne 1499
# 		Variable this, ligne 2117
# 		Variable output, ligne 2855
# 		Variable this, ligne 879
# 		Variable this, ligne 2118
# 		Variable matches, ligne 1500
# 		Variable this, ligne 2118
# 		Variable row, ligne 2857
# 		Variable this, ligne 2120
# 		Variable this, ligne 882
# 		Variable row, ligne 2860
# 		Variable this, ligne 2120
# 		Variable matches, ligne 1500
# 		Variable this, ligne 2124
# 		Variable maybe, ligne 3518
# 		Variable output, ligne 2865
# 		Variable this, ligne 883
# 		Variable this, ligne 2127
# 		Variable this, ligne 2867
# 		Variable this, ligne 2127
# 		Variable maybe, ligne 3520
# 		Variable table, ligne 2880
# 		Variable this, ligne 1509
# 		Variable dbh, ligne 884
# 		Variable this, ligne 2128
# 		Variable table, ligne 2881
# 		Variable this, ligne 3532
# 		Variable this, ligne 888
# 		Variable this, ligne 2129
# 		Variable this, ligne 3536
# 		Variable this, ligne 1512
# 		Variable table, ligne 2895
# 		Variable this, ligne 2132
# 		Variable this, ligne 3537
# 		Variable text, ligne 1538
# 		Variable text, ligne 1539
# 		Variable this, ligne 890
# 		Variable this, ligne 2133
# 		Variable this, ligne 2900
# 		Variable str, ligne 1552
# 		Variable this, ligne 2134
# 		Variable this, ligne 2901
# 		Variable EZSQL_ERROR, ligne 1553
# 		Variable this, ligne 3539
# 		Variable str, ligne 1555
# 		Variable this, ligne 2140
# 		Variable dbh, ligne 892
# 		Variable this, ligne 3539
# 		Variable this, ligne 1556
# 		Variable table, ligne 2907
# 		Variable query, ligne 2156
# 		Variable this, ligne 3542
# 		Variable this, ligne 1557
# 		Variable this, ligne 895
# 		Variable this, ligne 1559
# 		Variable this, ligne 2158
# 		Variable this, ligne 2909
# 		Variable this, ligne 1563
# 		Variable dbh, ligne 896
# 		Variable this, ligne 3544
# 		Variable EZSQL_ERROR, ligne 1562
# 		Variable this, ligne 1567
# 		Variable this, ligne 899
# 		Variable this, ligne 2161
# 		Variable this, ligne 3544
# 		Variable this, ligne 2161
# 		Variable info_type, ligne 3561
# 		Variable this, ligne 1573
# 		Variable col_offset, ligne 3561
# 		Variable this, ligne 2162
# 		Variable this, ligne 3562
# 		Variable query, ligne 2162
# 		Variable this, ligne 2162
# 		Variable column, ligne 2914
# 		Variable column, ligne 2915
# 		Variable this, ligne 901
# 		Variable this, ligne 3564
# 		Variable this, ligne 2163
# 		Variable col_offset, ligne 3565
# 		Variable column, ligne 2915
# 		Variable query, ligne 2164
# 		Variable this, ligne 1576
# 		Variable this, ligne 2918
# 		Variable this, ligne 2164
# 		Variable dbh, ligne 903
# 		Variable this, ligne 3568
# 		Variable this, ligne 2164
# 		Variable col, ligne 3568
# 		Variable column, ligne 2920
# 		Variable modes, ligne 918
# 		Variable col, ligne 3569
# 		Variable info_type, ligne 3569
# 		Variable this, ligne 2166
# 		Variable column, ligne 2921
# 		Variable modes, ligne 919
# 		Variable this, ligne 3574
# 		Variable col_offset, ligne 3574
# 		Variable this, ligne 920
# 		Variable info_type, ligne 3574
# 		Variable this, ligne 1579
# 		Variable this, ligne 2169
# 		Variable column, ligne 2922
# 		Variable query, ligne 2170
# 		Variable this, ligne 2171
# 		Variable this, ligne 921
# 		Variable this, ligne 3587
# 		Variable this, ligne 1585
# 		Variable this, ligne 2925
# 		Variable this, ligne 2172
# 		Variable this, ligne 923
# 		Variable this, ligne 2173
# 		Variable this, ligne 3599
# 		Variable query, ligne 2190
# 		Variable query_time, ligne 2190
# 		Variable message, ligne 3614
# 		Variable query_callstack, ligne 2190
# 		Variable error_code, ligne 3614
# 		Variable query_start, ligne 2190
# 		Variable this, ligne 930
# 		Variable query_data, ligne 2190
# 		Variable this, ligne 3615
# 		Variable this, ligne 1595
# 		Variable column, ligne 2932
# 		Variable query_data, ligne 2205
# 		Variable this, ligne 3618
# 		Variable query, ligne 2205
# 		Variable type, ligne 2932
# 		Variable query_time, ligne 2205
# 		Variable query_callstack, ligne 2205
# 		Variable this, ligne 3619
# 		Variable query_start, ligne 2205
# 		Variable query, ligne 2208
# 		Variable query_time, ligne 2209
# 		Variable query_callstack, ligne 2210
# 		Variable query_start, ligne 2211
# 		Variable type, ligne 2935
# 		Variable this, ligne 3620
# 		Variable this, ligne 2207
# 		Variable placeholder, ligne 2224
# 		Variable placeholder, ligne 2226
# 		Variable this, ligne 2936
# 		Variable this, ligne 3625
# 		Variable this, ligne 3626
# 		Variable this, ligne 1606
# 		Variable data, ligne 2686
# 		Variable this, ligne 956
# 		Variable message, ligne 3633
# 		Variable field, ligne 2686
# 		Variable i, ligne 958
# 		Variable mode, ligne 958
# 		Variable show, ligne 1630
# 		Variable this, ligne 1631
# 		Variable mode, ligne 959
# 		Variable show, ligne 1632
# 		Variable this, ligne 1632
# 		Variable i, ligne 960
# 		Variable this, ligne 1648
# 		Variable this, ligne 2239
# 		Variable error_code, ligne 3639
# 		Variable message, ligne 3639
# 		Variable this, ligne 1649
# 		Variable this, ligne 3639
# 		Variable message, ligne 3641
# 		Variable this, ligne 3641
# 		Variable this, ligne 2240
# 		Variable this, ligne 966
# 		Variable suppress, ligne 1665
# 		Variable this, ligne 1666
# 		Variable this, ligne 3657
# 		Variable this, ligne 967
# 		Variable suppress, ligne 1667
# 		Variable this, ligne 1667
# 		Variable query, ligne 2254
# 		Variable this, ligne 3661
# 		Variable this, ligne 2259
# 		Variable this, ligne 1677
# 		Variable this, ligne 969
# 		Variable this, ligne 3662
# 		Variable this, ligne 1678
# 		Variable query, ligne 2259
# 		Variable this, ligne 2970
# 		Variable prefix, ligne 983
# 		Variable this, ligne 1679
# 		Variable set_table_names, ligne 983
# 		Variable query, ligne 2270
# 		Variable this, ligne 1680
# 		Variable this, ligne 3664
# 		Variable table, ligne 2984
# 		Variable column, ligne 2984
# 		Variable this, ligne 1681
# 		Variable this, ligne 2271
# 		Variable prefix, ligne 985
# 		Variable this, ligne 1682
# 		Variable table, ligne 2985
# 		Variable this, ligne 3668
# 		Variable this, ligne 1684
# 		Variable query, ligne 2271
# 		Variable this, ligne 3669
# 		Variable this, ligne 1684
# 		Variable column, ligne 2986
# 		Variable this, ligne 3670
# 		Variable table, ligne 2300
# 		Variable data, ligne 2300
# 		Variable format, ligne 2300
# 		Variable this, ligne 1685
# 		Variable wp_version, ligne 3686
# 		Variable required_mysql_version, ligne 3686
# 		Variable prefix, ligne 989
# 		Variable this, ligne 2301
# 		Variable query, ligne 2710
# 		Variable this, ligne 1686
# 		Variable table, ligne 2301
# 		Variable table, ligne 3000
# 		Variable data, ligne 2301
# 		Variable column, ligne 3000
# 		Variable format, ligne 2301
# 		Variable this, ligne 3688
# 		Variable this, ligne 991
# 		Variable this, ligne 1689
# 		Variable this, ligne 992
# 		Variable required_mysql_version, ligne 3688
# 		Variable table, ligne 2330
# 		Variable data, ligne 2330
# 		Variable prefix, ligne 995
# 		Variable this, ligne 1689
# 		Variable this, ligne 995
# 		Variable format, ligne 2330
# 		Variable this, ligne 2331
# 		Variable this, ligne 3006
# 		Variable set_table_names, ligne 997
# 		Variable this, ligne 998
# 		Variable table, ligne 2331
# 		Variable data, ligne 2331
# 		Variable this, ligne 1694
# 		Variable format, ligne 2331
# 		Variable this, ligne 3010
# 		Variable table, ligne 998
# 		Variable prefixed_table, ligne 998
# 		Variable prefixed_table, ligne 999
# 		Variable table, ligne 2359
# 		Variable this, ligne 999
# 		Variable table, ligne 999
# 		Variable wp_version, ligne 3690
# 		Variable required_mysql_version, ligne 3690
# 		Variable this, ligne 1695
# 		Variable data, ligne 2359
# 		Variable format, ligne 2359
# 		Variable type, ligne 2359
# 		Variable this, ligne 2711
# 		Variable this, ligne 3012
# 		Variable this, ligne 1697
# 		Variable this, ligne 2360
# 		Variable table, ligne 3012
# 		Variable this, ligne 1002
# 		Variable this, ligne 1698
# 		Variable this, ligne 3708
# 		Variable this, ligne 1006
# 		Variable type, ligne 2362
# 		Variable allow_bail, ligne 1713
# 		Variable this, ligne 1006
# 		Variable this, ligne 1714
# 		Variable this, ligne 3019
# 		Variable this, ligne 1008
# 		Variable this, ligne 2366
# 		Variable this, ligne 3020
# 		Variable table, ligne 1008
# 		Variable prefixed_table, ligne 1008
# 		Variable this, ligne 3721
# 		Variable prefixed_table, ligne 1009
# 		Variable table, ligne 2366
# 		Variable this, ligne 1009
# 		Variable table, ligne 1009
# 		Variable data, ligne 2366
# 		Variable format, ligne 2366
# 		Variable this, ligne 3024
# 		Variable this, ligne 1012
# 		Variable this, ligne 3025
# 		Variable table, ligne 1012
# 		Variable prefixed_table, ligne 1012
# 		Variable this, ligne 3724
# 		Variable prefixed_table, ligne 1013
# 		Variable this, ligne 1723
# 		Variable this, ligne 1013
# 		Variable table, ligne 1013
# 		Variable value, ligne 2373
# 		Variable this, ligne 3029
# 		Variable blog_id, ligne 1028
# 		Variable db_cap, ligne 3744
# 		Variable network_id, ligne 1028
# 		Variable this, ligne 3745
# 		Variable value, ligne 2374
# 		Variable this, ligne 1731
# 		Variable this, ligne 1733
# 		Variable network_id, ligne 1029
# 		Variable value, ligne 2379
# 		Variable network_id, ligne 1030
# 		Variable this, ligne 1030
# 		Variable db_cap, ligne 3747
# 		Variable value, ligne 2380
# 		Variable this, ligne 3033
# 		Variable this, ligne 1033
# 		Variable this, ligne 1738
# 		Variable blog_id, ligne 1034
# 		Variable this, ligne 1034
# 		Variable this, ligne 1036
# 		Variable version, ligne 3751
# 		Variable this, ligne 1738
# 		Variable table, ligne 3050
# 		Variable column, ligne 3050
# 		Variable this, ligne 1036
# 		Variable this, ligne 1038
# 		Variable table, ligne 3051
# 		Variable version, ligne 3753
# 		Variable table, ligne 1038
# 		Variable prefixed_table, ligne 1038
# 		Variable column, ligne 3052
# 		Variable prefixed_table, ligne 1039
# 		Variable this, ligne 1039
# 		Variable table, ligne 1039
# 		Variable this, ligne 2388
# 		Variable this, ligne 1042
# 		Variable this, ligne 2389
# 		Variable this, ligne 3055
# 		Variable table, ligne 1042
# 		Variable prefixed_table, ligne 1042
# 		Variable this, ligne 3758
# 		Variable prefixed_table, ligne 1043
# 		Variable this, ligne 1753
# 		Variable this, ligne 1043
# 		Variable table, ligne 1043
# 		Variable this, ligne 1753
# 		Variable this, ligne 2389
# 		Variable this, ligne 3059
# 		Variable this, ligne 1753
# 		Variable blog_id, ligne 1057
# 		Variable this, ligne 3061
# 		Variable table, ligne 2427
# 		Variable data, ligne 2427
# 		Variable where, ligne 2427
# 		Variable table, ligne 3061
# 		Variable format, ligne 2427
# 		Variable where_format, ligne 2427
# 		Variable blog_id, ligne 1059
# 		Variable this, ligne 1756
# 		Variable this, ligne 1060
# 		Variable this, ligne 1756
# 		Variable this, ligne 1756
# 		Variable data, ligne 2428
# 		Variable where, ligne 2428
# 		Variable this, ligne 3067
# 		Variable this, ligne 1759
# 		Variable this, ligne 2432
# 		Variable this, ligne 1066
# 		Variable this, ligne 1760
# 		Variable table, ligne 2432
# 		Variable data, ligne 2432
# 		Variable this, ligne 1068
# 		Variable format, ligne 2432
# 		Variable this, ligne 1770
# 		Variable this, ligne 3071
# 		Variable this, ligne 1071
# 		Variable this, ligne 2436
# 		Variable scope, ligne 1104
# 		Variable prefix, ligne 1104
# 		Variable version, ligne 3775
# 		Variable blog_id, ligne 1104
# 		Variable table, ligne 2436
# 		Variable where, ligne 2436
# 		Variable scope, ligne 1105
# 		Variable where_format, ligne 2436
# 		Variable this, ligne 1107
# 		Variable this, ligne 1107
# 		Variable this, ligne 1779
# 		Variable field, ligne 2444
# 		Variable this, ligne 1780
# 		Variable value, ligne 2444
# 		Variable allow_bail, ligne 1780
# 		Variable this, ligne 3800
# 		Variable value, ligne 2445
# 		Variable this, ligne 1109
# 		Variable length, ligne 3085
# 		Variable this, ligne 1785
# 		Variable this, ligne 1113
# 		Variable this, ligne 3811
# 		Variable value, ligne 2450
# 		Variable this, ligne 1785
# 		Variable this, ligne 1785
# 		Variable this, ligne 1116
# 		Variable value, ligne 2451
# 		Variable length, ligne 3092
# 		Variable this, ligne 3812
# 		Variable field, ligne 2453
# 		Variable this, ligne 1785
# 		Variable value, ligne 2453
# 		Variable this, ligne 3814
# 		Variable value, ligne 2454
# 		Variable this, ligne 1788
# 		Variable this, ligne 1118
# 		Variable this, ligne 1788
# 		Variable this, ligne 1788
# 		Variable value, ligne 2459
# 		Variable this, ligne 1122
# 		Variable this, ligne 1788
# 		Variable value, ligne 2460
# 		Variable this, ligne 1125
# 		Variable this, ligne 1792
# 		Variable allow_bail, ligne 1792
# 		Variable prefix, ligne 1131
# 		Variable string, ligne 3139
# 		Variable blog_id, ligne 1132
# 		Variable this, ligne 1133
# 		Variable this, ligne 1135
# 		Variable this, ligne 2468
# 		Variable string, ligne 3141
# 		Variable this, ligne 2469
# 		Variable this, ligne 1136
# 		Variable this, ligne 2469
# 		Variable this, ligne 1137
# 		Variable string, ligne 3144
# 		Variable this, ligne 1137
# 		Variable k, ligne 1138
# 		Variable table, ligne 1138
# 		Variable table, ligne 2499
# 		Variable query, ligne 3159
# 		Variable where, ligne 2499
# 		Variable where_format, ligne 2499
# 		Variable this, ligne 3160
# 		Variable table, ligne 1139
# 		Variable where, ligne 2500
# 		Variable query, ligne 3165
# 		Variable table, ligne 1140
# 		Variable this, ligne 1807
# 		Variable table, ligne 1140
# 		Variable this, ligne 2504
# 		Variable table, ligne 1142
# 		Variable table, ligne 1142
# 		Variable table, ligne 2504
# 		Variable where, ligne 2504
# 		Variable where_format, ligne 2504
# 		Variable k, ligne 1144
# 		Variable this, ligne 3171
# 		Variable field, ligne 2511
# 		Variable value, ligne 2511
# 		Variable this, ligne 3175
# 		Variable value, ligne 2512
# 		Variable this, ligne 3180
# 		Variable value, ligne 2517
# 		Variable this, ligne 3181
# 		Variable value, ligne 2518
# 		Variable this, ligne 3182
# 		Variable db, ligne 1170
# 		Variable dbh, ligne 1170
# 		Variable this, ligne 2525
# 		Variable this, ligne 1822
# 		Variable dbh, ligne 1171
# 		Variable this, ligne 2526
# 		Variable this, ligne 1172
# 		Variable this, ligne 2526
# 		Variable this, ligne 1175
# 		Variable this, ligne 1825
# 		Variable this, ligne 3190
# 		Variable this, ligne 1826
# 		Variable db, ligne 1176
# 		Variable this, ligne 1827
# 		Variable table, ligne 2546
# 		Variable data, ligne 2546
# 		Variable this, ligne 3195
# 		Variable format, ligne 2546
# 		Variable col, ligne 3195
# 		Variable db, ligne 1178
# 		Variable this, ligne 1830
# 		Variable this, ligne 2547
# 		Variable this, ligne 1832
# 		Variable data, ligne 2547
# 		Variable col, ligne 3196
# 		Variable format, ligne 2547
# 		Variable this, ligne 1832
# 		Variable this, ligne 1181
# 		Variable this, ligne 1834
# 		Variable this, ligne 1835
# 		Variable this, ligne 2552
# 		Variable col, ligne 3200
# 		Variable this, ligne 1836
# 		Variable table, ligne 2552
# 		Variable this, ligne 1836
# 		Variable this, ligne 1836
# 		Variable this, ligne 2557
# 		Variable data, ligne 3220
# 		Variable data, ligne 3223
# 		Variable host, ligne 1858
# 		Variable table, ligne 2557
# 		Variable value, ligne 3223
# 		Variable value, ligne 3224
# 		Variable this, ligne 2562
# 		Variable value, ligne 3226
# 		Variable host, ligne 1864
# 		Variable value, ligne 3227
# 		Variable db, ligne 1190
# 		Variable value, ligne 3228
# 		Variable host, ligne 1866
# 		Variable field, ligne 2567
# 		Variable value, ligne 2567
# 		Variable value, ligne 2568
# 		Variable field, ligne 2568
# 		Variable field, ligne 2569
# 		Variable host, ligne 1867
# 		Variable value, ligne 3242
# 		Variable this, ligne 1199
# 		Variable value, ligne 3252
# 		Variable this, ligne 3252
# 		Variable value, ligne 3252
# 		Variable db, ligne 1200
# 		Variable this, ligne 2576
# 		Variable this, ligne 2582
# 		Variable db, ligne 1206
# 		Variable value, ligne 3260
# 		Variable data, ligne 2605
# 		Variable format, ligne 2605
# 		Variable value, ligne 3261
# 		Variable format, ligne 2606
# 		Variable allow_bail, ligne 1911
# 		Variable value, ligne 3261
# 		Variable this, ligne 1912
# 		Variable data, ligne 2609
# 		Variable field, ligne 2609
# 		Variable this, ligne 1913
# 		Variable this, ligne 1217
# 		Variable format, ligne 2615
# 		Variable this, ligne 1913
# 		Variable string, ligne 1235
# 	Définitions non référencées/utilisées:
# 		Variable formats, ligne 2384
# 		Variable conditions, ligne 2464
# 		Variable length, ligne 3075
# 		Variable conditions, ligne 2521
# 		Variable length, ligne 3077
# 		Variable collate, ligne 857
# 		Variable connection_charset, ligne 3323
# 		Variable length, ligne 3330
# 		Variable connection_charset, ligne 3325
# 		Variable fields, ligne 2383
# 		Variable fields, ligne 2463
# 		Variable allowed_format, ligne 1445
# 		Variable table, ligne 2908
# 		Variable connection_charset, ligne 3320
# 		Variable querry, ligne 3464
# 		Variable modes_str, ligne 964
# 		Variable string, ligne 1346
#
#
# For file: ../tp4/part_2/file2.php.cfg.json
# 	Références non définies:
# 		Variable meta_type, ligne 3
# 		Variable object_id, ligne 8
# 		Variable object_id, ligne 3
# 		Variable meta_key, ligne 3
# 		Variable meta_type, ligne 14
# 		Variable single, ligne 3
# 		Variable meta_type, ligne 4
# 		Variable meta_key, ligne 16
# 		Variable simgle, ligne 19
# 		Variable object_id, ligne 4
# 		Variable meta_type, ligne 12
# 	Définitions non référencées/utilisées:
#
#
# For file: ../tp4/part_2/file1.php.cfg.json
# 	Références non définies:
# 		Variable filename, ligne 4
# 		Variable filename, ligne 3
# 	Définitions non référencées/utilisées:
# 		Variable fp, ligne 14

# %% [markdown]
# Nos résultats comportent un certains nombre d'anomalies:
#
# *   Paramètres de fonction: En considérant uniquement les définitions de la forme (Variable = Expression ∧ Literal), les paramètres d'une fonction sont considérés comme des références non définies (on le voit facilement dans l'analyse du fichier `part_2/file1.php` avec la variable `filename`). Cela entraîne des faux positifs dans les références non définies.
# *   Attribut de classe: Avec notre implémentation, nous ne considérons pas les attributs de classe (exemple: `$this->ready`) comme une seule variable (car il y a 3 noeuds en vérité). Cela entraîne des bugs, avec l'exemple précédent `this` et `ready` seront considérées comme 2 variables indépendantes et donc ne seront pas correctement comptabilisées parmi les références et les définitions.
# *   Élément d'un tableau: Pour les même raisons que les attributs de classe, les éléments de tableau (exemple: `$value['charset']`) ne sont pas correctement comptabilisés. Mais ce cas est encore plus complexe car il est aussi possible de faire référence à l'élément d'un tableau sans l'appeler par son index ou sa clé (exemple: `foreach ( $data as $col => $value )`)
# *   Variable à l'intérieur d'une chaîne de caractères: Certaines variables sont utilisés dans des chaîne de caractères (exemple ligne 2523 du fichier `part_2/file3.php`: ```"DELETE FROM `$table` WHERE $conditions"```) et ces variables ne sont pas associées à un noeud `Variable` donc ces références ne sont pas détectées. Cela entraîne des faux positifs dans les définitions non référencées.
#
#
# Mais l'algorithme détecte tout de même des définitions non utilisés parmi les fichiers du répertoire `part_2/` (liste non exhaustive):
# *   `fp` dans `part_2/file1.php`
# *   `querry` dans `part_2/file3.php` (ligne 3464)

# %% [markdown]
# ## 2.2 Filtration des données utilisateur

# %%
def analyze_part3(directory):
    for filename in os.scandir(directory):
        if filename.is_file() and filename.name.endswith(".php.cfg.json"):
            reader = CFGReader()
            cfg = reader.read_cfg(filename.path)
            visitor = CFGVisitor(cfg)
            visitor.check_prepare_query_params_filtered()

analyze_part3("../tp4/part_3/")
